# %%
#sklearn toy datasets
import pandas as pd
from sklearn.datasets import load_boston
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.linear_model import LinearRegression

# %%
dataBoston = load_boston()
#buatdataframe
df = pd.DataFrame(
    dataBoston['data'],
    columns = dataBoston['feature_names']
)
df['price']= dataBoston['target']
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
korelasi = df.corr()
plt.imshow(korelasi, cmap = 'RdBu')
plt.colorbar()
# plt.xticks('')
# sb.heatmap(korelasi)
plt.xticks(np.arange(14), list(df.columns),rotation = 90)
plt.yticks(np.arange(14), list(df.columns))
plt.show()

# %%
# 4. Model ML Regression
model = LinearRegression()
model.fit(df[['ZN','CHAS','RM','DIS','B']], df['price'])
model.predict(df[['ZN','CHAS','RM','DIS','B']])
# Out:
# array([ 2.58962896e+01,  2.33924484e+01,  2.94366821e+01,  2.77949618e+01,
#         2.90455807e+01,  2.32184386e+01,  2.07555905e+01,  2.20073497e+01,
#         1.73971944e+01,  2.03122100e+01,  2.34865351e+01,  2.06517584e+01,
#         1.96656890e+01,  1.96423024e+01,  2.04684717e+01,  1.87226835e+01,
#         1.93287125e+01,  1.98081763e+01,  1.33010156e+01,  1.78694560e+01,
#         1.62703760e+01,  1.97834209e+01,  2.13141476e+01,  1.85953319e+01,
#         1.94320726e+01,  1.46796651e+01,  1.80841930e+01,  1.83494866e+01,
#         2.38618073e+01,  2.51551955e+01,  1.69630521e+01,  2.02459226e+01,
#         1.59167315e+01,  1.69075373e+01,  1.74964460e+01,  1.97365797e+01,
#         1.85408775e+01,  1.89746388e+01,  1.98398538e+01,  2.93607350e+01,
#         3.28080332e+01,  2.58029864e+01,  2.09253949e+01,  2.15229398e+01,
#         2.02629235e+01,  1.74316408e+01,  1.82674063e+01,  2.00332688e+01,
# ...

# %%
model.predict(df.head(1)[['ZN','CHAS','RM','DIS','B']])
# Out:
# array([25.89628963])

# %%
df.head(1)['price']
# Out:
# 0    24.0
# Name: price, dtype: float64

# %%
model = LinearRegression()
model.fit(df[['CRIM']], df['price'])
model.predict(df.head(1)[['CRIM']])
# Out:
# array([24.03048217])

# %%
df.head(1)['price']
# Out:
# 0    24.0
# Name: price, dtype: float64
